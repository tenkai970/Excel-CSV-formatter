# %%
from Code.processing import Object
import pandas as pd
import os

# %%
os.getcwd()

# %%
out = r'Output\\'
dts = r'Datasets\\'

# %%
fpath = os.getcwd() + "\\Datasets\\"
a  = Object('test1.xlsx'  ,sep = ';',s_name=0)
b  = Object('test1.xlsx' ,sep = ';',s_name=0)
all_ = [a,b]
on = 'ID'

# %%
print(*[f'{obj.path}: \n  {obj.col}' for obj in all_], sep='\n\n')

# %%
merge = a.join(b,on=on)

# %%
merge.export()
