# %%
from Code.processing import Object
import pandas as pd
import os

# %%
os.getcwd()

# %%
fpath = os.getcwd() + "\\Output\\" #mpath=fpath
a  = Object('test1.xlsx' ,sep = ';')
b  = Object('test.xlsx' ,sep = ';')
all_ = [a,b]

# %%
print(*[f'{obj.path}: \n  {obj.col}' for obj in all_], sep='\n\n')

# %%
conc = Object.concat(a, b, axis = 0)

# %%
conc.drop_duplicates()
